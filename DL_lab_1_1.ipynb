# %% [markdown]
# <a href="https://colab.research.google.com/github/MeedumiRashmika/Dl-lab1/blob/main/DL_lab_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)**Create a random 4x4 array from an exponential distribution. Refer numpy functions.**

# %%
import numpy as np

# %%
exponential_array = np.random.exponential(scale=1.0, size=(4, 4))

# %%
print("4x4 Exponential Distribution Array:")
print(exponential_array)
# Out:
# 4x4 Exponential Distribution Array:
# [[2.76411994 1.60938273 0.40590895 1.30632118]
#  [0.12106661 0.21771541 1.14464535 2.16325477]
#  [0.03941097 0.35836203 0.73852015 1.56391724]
#  [0.04228665 1.88064531 2.16231823 0.90031096]]

# %% [markdown]
# 2)Create a random 100000x1 array from the same exponential distribution and visualize the
# distribution histogram along with uniform and normal distributions. Use the code given
# below and do the necessary changes. Change the number of bins and the plot view to make
# the visualization better.
# **bold text**

# %%
import matplotlib.pyplot as plt

# %%
exponential_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)  # Uniform [0, 1)
normal_data = np.random.normal(loc=0.0, scale=1.0, size=100000)

# %%
plt.hist(exponential_data, bins=100, density=True, histtype="step", label="Exponential", color="green")
plt.hist(uniform_data, bins=100, density=True, histtype="step", label="Uniform", color="blue")
plt.hist(normal_data, bins=100, density=True, histtype="step", label="Normal", color="red")

plt.title("Random Distributions: Exponential vs Uniform vs Normal")
plt.xlabel("Value")
plt.ylabel("Density")
plt.axis([-2, 8, 0, 1])
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# %% [markdown]
# 3)**Using** matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_title("3D Plot of Z = X² + Y²")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z = X² + Y²")
plt.show()

# %% [markdown]
# 4)Calculate the pearson standard coefficient and spearman rank correlation for the [HP,
# Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the
# results using heatmaps. Make sure the values are displaced in the heatmap as well.**bold text**

# %%
import seaborn as sns
import pandas as pd
from scipy.stats import spearmanr, pearsonr

# %%
df = sns.load_dataset('iris').dropna()

# %%
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
data = df[features]

# %%
pearson_corr = data.corr(method='pearson')
spearman_corr, _ = spearmanr(data)
spearman_corr = pd.DataFrame(spearman_corr, index=features, columns=features)

print("Pearson Correlation Matrix:")
display(pearson_corr)

print("\nSpearman Rank Correlation Matrix:")
display(spearman_corr)
# Out:
# Pearson Correlation Matrix:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# Spearman Rank Correlation Matrix:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Pearson Correlation Coefficient")

plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Spearman Rank Correlation")

plt.tight_layout()
plt.show()
